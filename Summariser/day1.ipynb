# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI
from scraper import fetch_website_contents, fetch_website_links
from pw_scraper import stock_data
import asyncio

# %%
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    print("OPENAI_API_KEY is not set")
elif not api_key.startswith("sk-"):
    print("OPENAI_API_KEY is not a valid OpenAI API key")
elif api_key.strip() != api_key:
    print("OPENAI_API_KEY has extra whitespace")
else:
    print("OPENAI_API_KEY is valid")

openai = OpenAI(api_key=api_key)
# Out:
# OPENAI_API_KEY is valid

# %%
message = "Hello, GPT! this is my first course message to you"
message = [{"role": "user", "content": message}]
message
# Out:
# [{'role': 'user',
#   'content': 'Hello, GPT! this is my first course message to you'}]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=message)
response.choices[0].message.content
# Out:
# 'Hi there! Welcome, and congrats on starting this course with me. I’m here to help you learn faster and stay organized.\n\nI can help with:\n- Explanations and step-by-step reasoning\n- Quick summaries and concept maps\n- Practice problems with solutions\n- Flashcards and spaced-repetition ideas\n- Study plans, deadlines, and progress tracking\n- Debugging code or projects\n- Essay/assignment brainstorming and editing\n\nTo tailor things, a few quick questions:\n- What is your course about (subject and level)?\n- Do you have a syllabus or topics list you want covered?\n- Any upcoming tests, quizzes, or deadlines?\n- Do you prefer short, concise explanations or deep dives with examples?\n- Would you like me to create a study plan or a set of practice problems now?\n\nIf you want, we can start right away with:\n- A quick diagnostic quiz on a topic you’re studying\n- A 7-day study plan tailored to your schedule\n- A set of practice problems with solutions\n\nTell me what you’d like to d
# ...

# %%
site = fetch_website_contents("https://savvyalgostudio.com")
print(site)
# Out:
# Savvy Algo Studio — Growth-Focused AI Agency
#
# AI Systems & Digitalization for Operations-Driven Businesses
# We Digitalize Your Operations.
# Then We Make Them
# Intelligent.
# We build the systems your business runs on — your CRM, your call center, your follow-up — then add the AI that makes them perform. You own all of it.
# Book a Free 30-Min Strategy Call
# See What We've Built
# Or call us now —
# +1 (307) 374-8824
#  · We answer around the clock
# 7+ years in production
# ·
# Live across the UK, US, GCC, EU, Canada & Australia
# ·
# Built for you, owned by you
# AI Call Center · Live
# Inbound desk
# ACTIVE
# 22
# live calls
# 71%
# containment
# +0.7
# CSAT
# CRM activity
# just now
#
# Lead qualified
# +$1,840 pipeline
#
# Member reactivated
# tier: gold
#
# Chargeback rebuttal sent
# auto-filed
# Retention rate
# +18.4% MoM
# ▲ rising
# Sound Familiar?
# Where Your Business Is Losing Money Right Now
# ...

# %% [markdown]
# ## Types of prompts
#
# You may know this already - but if not, you will get very familiar with it!
#
# Models like GPT have been trained to receive instructions in a particular way.
#
# They expect to receive:
#
# **A system prompt** that tells them what task they are performing and what tone they should use
#
# **A user prompt** -- the conversation starter that they should reply to

# %%
system_prompt = """
You are a snarky assistant that analyzes the contents of a website,
and provides a short, snarky, humorous summary, ignoring text that might be navigation related.
Respond in markdown. Do not wrap the markdown in a code block - respond just with the markdown.
"""

# %%
user_prompt_prefix = """
Here are the contents of a website.
Provide a short summary of this website.
If it includes news or announcements, then summarize these too.

"""

# %%
def message_for(website):

    return [{
        "role": "system",
        "content": system_prompt
    },
    {
        "role": "user",
        "content": user_prompt_prefix + website
    }]

# %%
message_for(site)
response = openai.chat.completions.create(model="gpt-5-nano", messages=message_for(site))
response.choices[0].message.content
# Out:
# 'Savvy Algo Studio is an ops-automation shop that promises to build end-to-end, AI-powered systems for your business—your CRM, call center, and follow-up—then hand you the keys so you “own all of it.”\n\nWhat they claim to do\n- Build and AI-ify the core systems your business runs on (CRM, inbound call center, follow-up workflows).\n- Deliver a unified stack you own, with AI baked in to boost performance.\n- Offer a free 30-minute strategy call and a showroom of what they’ve built.\n\nCreds and reach\n- 7+ years in production.\n- Live across the UK, US, GCC, EU, Canada, Australia.\n\nLive metrics they flaunt\n- AI Call Center: 22 live calls, 71% containment, +0.7 CSAT, inbound desk active.\n- Pipeline and retention signals: +$1,840 pipeline, +18.4% MoM retention.\n- A snapshot into their “you should fix these leaks” sales pitch.\n\nThe pitch (what they say you’re leaking)\n- Revenue leaks from unanswered calls, disconnected data, and sloppy follow-up.\n- Your team doing system-level 
# ...

# %%
def summarizer(url):
    website = fetch_website_contents(url)

    response = openai.chat.completions.create(
        model="gpt-4.1-mini",
        messages = message_for(website),
    )

    return response.choices[0].message.content

# %%
summarizer("https://savvyalgostudio.com")
# Out:
# "# Savvy Algo Studio: Because Your Business Deserves an AI Butler\n\nWelcome to Savvy Algo Studio, the AI fairy godmother for operations-driven businesses. They build and digitalize your CRM, call center, and follow-ups — then sprinkle AI magic on top to make your business run smarter, faster, better. You actually own the whole thing, so no sneaky subscription traps here.\n\n## Highlights:\n- 7+ years rocking live AI systems across the UK, US, GCC, EU, Canada, and Australia.\n- Real-time AI call centers handling 22 calls and boosting customer satisfaction (CSAT) and retention like a boss.\n- Fixes your leaky business funnel by automating the grunt work your team hates — say goodbye to chasing leads, juggling data from five different places, and tools that just can’t play nice.\n- Perfect for businesses who vaguely feel AI *could* help but have no clue where to start or who to trust.\n\n## Announcement summary?\nNo explicit news blasts here. Just the usual bragging about skyrocketing 
# ...

# %%
def display_summary(url):
    summary = summarizer(url)
    display(Markdown(summary))

# %%
display_summary("https://savvyalgostudio.com")
# Out:
# # Savvy Algo Studio: AI Wizards for Your Messy Business Ops
#
# This site pitches itself as your go-to AI agency that fixes the nightmare of disconnected tools, ghosted calls, and manual busywork swooping away your revenue. They build bespoke AI-powered CRMs and call center systems that your team actually owns (no renting nightmares here).
#
# **Highlights:**
# - 7+ years of annoying operations solved
# - Clients span UK, US, GCC, EU, Canada, Australia (because chaos is global)
# - Real-time AI call center stats: 22 active calls, 71% containment, +0.7 CSAT (Customer Satisfaction, but who’s counting?)
# - Boosted retention by +18.4% monthly (take that, customer churn!)
#
# **Main Drama: What's bleeding your business dry?**
# - Your team stuck doing robot-work a system should handle
# - Customer data scattered like confetti over five different apps
# - Tools that refuse to chit-chat, causing leads and payments to vanish
# - AI seems like magic but you’re too scared to conjure it wrong
# ...

# %%
results = stock_data()
# Out:
# C:\Users\madil\AppData\Local\Temp\ipykernel_30676\951240327.py:1: RuntimeWarning: coroutine 'stock_data' was never awaited
#   results = stock_data()
# ...
