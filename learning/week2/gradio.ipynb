# %%
import os
from dotenv import load_dotenv
from openai import OpenAI
import gradio as gr

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
openai = OpenAI()

# %%
def shout(text):
    print(f"Shout has been called with input {text}")
    return text.upper()

# %%
shout("hello")
# Out:
# Shout has been called with input hello
# 'HELLO'

# %%
gr.Interface(fn=shout, inputs = "textbox", outputs="textbox").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input Hello
# Created dataset file at: .gradio\flagged\dataset1.csv

# %%
gr.Interface(fn=shout, inputs = "textbox", outputs="textbox").launch(inbrowser=True, auth=("adil", "test123"))
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Shout has been called with input jfjdfk

# %%
# Let's wrap a call to GPT-4.1-mini in a simple function

system_message = "You are a helpful assistant"

def message_gpt(prompt):
    messages = [{"role": "system", "content": system_message}, {"role": "user", "content": prompt}]
    response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
    return response.choices[0].message.content

# %%
message_input = gr.Textbox(label ="Your message:", info="Enter message for gpt", lines = 7)
message_output = gr.Textbox(label="Response", lines = 8)

view = gr.Interface(
    title="GPT",
    fn=message_gpt,
    inputs=[message_input],
    outputs = [message_output],
    examples=["hello", "howdy"], 
    flagging_mode ="never"
    )
view.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
from turtle import title


system_message = """You are an helpful assistant that respond in markdown without code blocks"""
message_input = gr.Textbox(label ="Your message:", info="Enter message for gpt", lines = 7)
message_output = gr.Textbox(label="Response", lines = 8)

view = gr.Interfacr(
    fn=message_gpt,
    title="GPT"
)
