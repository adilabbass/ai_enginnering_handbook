# %%
# imports

import os
from dotenv import load_dotenv
from IPython.display import Markdown, display
from openai import OpenAI

# %%
load_dotenv(override=True)
api_key = os.getenv("OPENAI_API_KEY")

if not api_key:
    print("OPENAI_API_KEY is not set")
elif not api_key.startswith("sk-"):
    print("OPENAI_API_KEY is not a valid OpenAI API key")
elif api_key.strip() != api_key:
    print("OPENAI_API_KEY has extra whitespace")
else:
    print("OPENAI_API_KEY is valid")

openai = OpenAI(api_key=api_key)
# Out:
# OPENAI_API_KEY is valid

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

# %%
display(Markdown(response.content))
# Out:
# How many LLM engineers does it take to change a lightbulb?
#
# One to write the prompt, one to tune the hyperparameters, one to blame the dataset, one to build a reward model — and the rest to argue whether the lightbulb's behavior is an emergent property.

# %%
from litellm import completion

response = completion(model="openai/gpt-4.1", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student stop arguing with the language model?
#
# Because they realized it would just keep generating counterpoints until they finally agreed to fine-tune!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49685
# Output tokens: 57
# Total tokens: 49742
# Total cost: 3.7520 cents

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
from litellm import completion

response = completion(model="openai/gpt-4.1", messages=question)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# In **Shakespeare’s _Hamlet_**, when Laertes bursts into the castle and demands, **"Where is my father?"** the reply comes from Claudius:
#
# > **Gertrude:** *But not by him.*
# >
# > **Claudius:** *Let him demand his fill.*
#
# However, the direct and memorable answer is given by **Gertrude**, who says:
#
# > **"Dead."**
#
# So to summarize:
# **Laertes:** "Where is my father?"
# **Gertrude:** "Dead."

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 25
# Output tokens: 110
# Total tokens: 135
# Total cost: 0.0930 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
from litellm import completion

response = completion(model="openai/gpt-5.4-mini", messages=question)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Horatio’s reply is:
#
# **“He is dead and gone, lady, / He is dead and gone.”**
#
# That’s the line from **Ophelia’s song** in Act IV, Scene V, when Laertes asks, “Where is my father?”

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 49685
# Output tokens: 57
# Total tokens: 49742
# Total cost: 3.7520 cents
